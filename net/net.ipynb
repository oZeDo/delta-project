# %%
# !pip install -q textgenrnn
from google.colab import files
from textgenrnn import textgenrnn
from datetime import datetime
import os
# Out:
# Using TensorFlow backend.

# %%
model_cfg = {
    'word_level': False,   # set to True if want to train a word-level model (requires more data and smaller max_length)
    'rnn_size': 256,   # number of LSTM cells of each layer (128/256 recommended)
    'rnn_layers': 6,   # number of LSTM layers (>=2 recommended)
    'rnn_bidirectional': False,   # consider text both forwards and backward, can give a training boost
    'max_length': 30,   # number of tokens to consider before predicting the next (20-40 for characters, 5-10 for words recommended)
    'max_words': 10000,   # maximum number of words to model; the rest will be ignored (word-level model only)
}

train_cfg = {
    'line_delimited': True,   # set to True if each text has its own line in the source file
    'num_epochs': 20,   # set higher to train the model for longer
    'gen_epochs': 5,   # generates sample text from model after given number of epochs
    'train_size': 0.8,   # proportion of input data to train on: setting < 1.0 limits model from learning perfectly
    'dropout': 0.0,   # ignore a random proportion of source tokens each epoch, allowing model to generalize better
    'validation': False,   # If train__size < 1.0, test on holdout dataset; will make overall training slower
    'is_csv': False   # set to True if file is a CSV exported from Excel/BigQuery/pandas
}

# %%
file_name = "my_small_file.txt"
model_name = 'article'   # change to set file name of resulting trained models/texts

# %%
textgen = textgenrnn(name=model_name)

train_function = textgen.train_from_file if train_cfg['line_delimited'] else textgen.train_from_largetext_file

train_function(
    file_path="file_name,
    new_model=True,
    num_epochs=train_cfg['num_epochs'],
    gen_epochs=train_cfg['gen_epochs'],
    batch_size=1024,
    train_size=train_cfg['train_size'],
    dropout=train_cfg['dropout'],
    validation=train_cfg['validation'],
    is_csv=train_cfg['is_csv'],
    rnn_layers=model_cfg['rnn_layers'],
    rnn_size=model_cfg['rnn_size'],
    rnn_bidirectional=model_cfg['rnn_bidirectional'],
    max_length=model_cfg['max_length'],
    dim_embeddings=100,
    word_level=model_cfg['word_level'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# 999 texts collected.
# Training new model w/ 6-layer, 256-cell LSTMs
# Training on 1,324,200 character sequences.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/20
# 1293/1293 [==============================] - 530s 410ms/step - loss: 3.4721
# Epoch 2/20
# 1293/1293 [==============================] - 531s 410ms/step - loss: 1.9972
# Epoch 3/20
# 1293/1293 [==============================] - 531s 411ms/step - loss: 1.4982
# Epoch 4/20
# 1293/1293 [==============================] - 531s 411ms/step - loss: 1.3472
# Epoch 5/20
# 1293/1293 [==============================] - 531s 410ms/step - loss: 1.2596
# ####################
# Temperature: 0.2
# ####################
# В Калининграде по причине на предварительные программы в субботу в последнее время в субботу в поле не менее политики по предварительным преступлениям. В то же время в этом году в политике признал на противостоянии в полиции в полиции проводится в политике в связи с тем, что не получилось в стране
#
# В Калининграде против настоящей Оферты. 4.2. Мэйл.Ру вправе: 4.4.1. прекратить предоставление Подписчиком обязательств и/или гарантий по Договору, о тот как был относительный проект, в котором по делам против приводят в конце не было не подозреваемого командующего по пригороду на представители про
#
# В России с конца получается в расследовании в проведении полиции в конце недели в конце начала сезона в поле не выполнялся в поле на поле на противостоянии в субботу в какой-то стране продолжается в соответствии с законодательством Российской Федерации на пресс-службе Грузии в сообщении проведет п
#
# ####################
# Temperature: 0.5
# ####################
# Фото: Юлия Варрин объяснил по программирующим сезоном в полном объеем заметили в соответствии с законодательством Российской Федерации направления сети иностранных в рамках программы Мария Васила Самара, который заявил на то, что они не подписали политику возбуждено уголовное дело (3:3). Это не уд
#
# МОСКВА, 4 окт — РИА Новости . Глава компании представила пресс-служба МВД по делам собственного предварительного ведомства. На него и настоящий оперативные проблемы, которые признал возможные предприятие в причине инструкции на развитие победа в пятницу. Это не позволяют участие в продукции по при
#
# Фото Федерального плутония и все магазина на предложении политической стороны, который приводит континент на настоящий момент, конечно, повести не мима не позволит себя континент на прошедшие полиции в народный раз в повышенной вопросах судов. В июле 2006 года у командира приголования комментируем
#
# ####################
# Temperature: 1.0
# ####################
# Формулировки: составляющий регион на 17% как страна блокчетинского Холландии на латриалище, чтобы выступать по вычебной сайте. Момент Асада недопустился на сотрудничестве предложение оскорблений. Так считает, что ХШ чего. Это ж связано, что дальше группратально были выпищены на потанции во Владжи
#
# Как полиция счащала настоящий дебютирование Подписчиком положений настоящей Оферты считается ему ситуация основательно.
#
#  rweettercangalos Савис Юнан и в 15:30 п 16:56 с адресам 9:0) оппозиционных дорги четко потом: и помогает, повышают на самым защите фран-человек.
#
# Epoch 6/20
# 1293/1293 [==============================] - 530s 410ms/step - loss: 1.1948
# Epoch 7/20
# 1293/1293 [==============================] - 531s 411ms/step - loss: 1.1397
# Epoch 8/20
# 1293/1293 [==============================] - 530s 410ms/step - loss: 1.0905
# Epoch 9/20
# 1293/1293 [==============================] - 530s 410ms/step - loss: 1.0442
# Epoch 10/20
# 1293/1293 [==============================] - 530s 410ms/step - loss: 0.9976
# ####################
# Temperature: 0.2
# ####################
# Как сообщалось, что в полном сообщении требования правилам и полностью подразумеваться на посту против России приступили к расследованию коррупциогенностей в стране в области сообщения, что становятся поддержать и не поддерживает этим летом. После проблем в полном объеме, включая все получили подд
#
# В последнем матче было затем продолжить следующему году на последние два года и просто против страны и страны стали странами и странами и странами и странами и странами и странами и странами и странами и странами и странами и простой проблемы с помощью половиной и политической стороны в Сочи на по
#
# Фото: РИА Новости Портала Алексеевича поставила свои поддержки и поддержки. Об этом сообщает пресс-служба клуба.
#
# ####################
# Temperature: 0.5
# ####################
# МОСКВА, Марк Турции, заявил начало свои право на происхождение по проведению технических расследований на вопросы на совещании судей, которые поддерживает достойный сетев с более местом проблемы, сообщает агентство Рейтер применения министерства иностранных дел России и США об утилизации плутония,
#
# Алексей Мирчика, Сергей Балышец отказал мощность сотрудничества с Россией по Сирии Максим Саакашвили в противодействии как стоимость от полученных моделей. Он поддерживает нефть и от поставка. Получил трое того, что мы происходилось у меня российского военного ведомства в отношении в качестве авто
#
# В Восточной качестве Алексеевенко образован от последних месяцев от случая и возникает в совете дипломатической системы бизнеса в краснодарском Акерине Как сообщает пресс-служба МВД по предоставлению возможности просмотра и размещения комментариев в рамках Сервиса. 2. ПОРЯДОК ОПЛАТЫ 5.1. Оплата пр
#
# ####################
# Temperature: 1.0
# ####################
# Гьезин, пишет габетного правительства станет игры вас песыказки, мском помочь риск уменьш, быть расходов, стаивать экс-кумпинаты общей.Казаниных Ярославой Англии, поборются контрольные игры, но не усрешулся с Кризищенко. Три части активно передала на сейтке Северо-Завиз БСУ. Тем более капитан Шара
#
# Областей Apple Xazure Sericer, мы рассказали, что в конфраде" новые придумать угрозы главной технологии и тех же ситуацы с инвестиции Орана была сделана работать от тихого молодого направления Парасадой и в сунгусенной коробке, утверждают, что рачалось у него. Поэтому, на гранепе образился по тенн
#
# Экс-Полос Алексея Мартинова. Матероны идентайнаризмов нового исполнения Дмитрия Обама заявила в интернете автомобилей могут создать установку простой политики будут хотить законом, конечно жалом, но не прямо моей. Итого-американский знаменит еще необходимой реборгию с 36,7 миллиарда группового гор
#
# Epoch 11/20
# 1293/1293 [==============================] - 530s 410ms/step - loss: 0.9511
# Epoch 12/20
# 1293/1293 [==============================] - 530s 410ms/step - loss: 0.9027
# Epoch 13/20
# 1293/1293 [==============================] - 530s 410ms/step - loss: 0.8530
# Epoch 14/20
# 1293/1293 [==============================] - 530s 410ms/step - loss: 0.8012
# Epoch 15/20
# 1293/1293 [==============================] - 530s 410ms/step - loss: 0.7463
# ####################
# Temperature: 0.2
# ####################
# Фото: РИА Новости Рейгин Мексики и Сергей Исад. На настой он приехал в Грузию 30 сентября 2016 года по маршруту Трофименко на своем получении водителя подряда документов, когда выступил в процессе розыгрыша Венгрии пострадали на поддержку реформ и обстрелов. На данный момент, собрались от полномоч
#
# Короткая ссылка 1 октября 2016 года в Сирии и Ираке Гран-по финансовой информации и социальные войска в Сирии. По словам активности встретили на собственное подозрение в Сирии Подписаться Политиком и Донецки Иванер Макс Тамразян в состав комплекта направлены в коллекцию в стране в целом морг, посл
#
# В России могут быть все своими собственными и советами не имеют надежду. Может, столько тогда смогут поставить очередное запрет по инвестициям и просто при поддержке расскрыли на себя ответственность за следующий уроке, а также признака региона. Проект против России пришло в господин Валитов в сер
#
# ####################
# Temperature: 0.5
# ####################
# Фото: РИА Новости Необходя на высоте. В октябре 2016 года не отказался в соответствии с законодательством РФ. Использование материалов, опубликованных на сайте www.mk.ru допускается только с письменного разрешения правообладателя и с обязательной прямой гиперссылкой на страницу, с которой материал
#
# МОСКВА, 4 окт — РИА Новости. Министр иностранных дел Павел Владимир позиций России в рамках почтового сервиса Мэйл.Ру, размещенного по адресу https://news.mail.ru . Способы оплаты Подписки отличные от тех, что указаны на страницах Сервиса, не предусмотрены. 6. ОТКАЗ ОТ ГАРАНТИЙ СЕРВИС ФУНКЦИОНИРУЕ
#
# Сегодня, 4 октября, пресс-служба канала ”1+1» дирекцов: читайте также На Украине признал программу признаков на вооружение и наших акций полиции в области потребительской команды приняли участие в примере 500 человек. Однако возможность рассматриваться не только на настроение в особо крупном разме
#
# ####################
# Temperature: 1.0
# ####################
#   10:08. То есть систематар у состав — из приемлемой степени против 18 декабря 2015 года. Основные риск покинули в ФНЛ. Читайте также Петри Кириллфочан приходится 3 руки и нелегально поразоваться в мире, необходимо видео"Болотолона, офицеры — родился Анештабульца, посоверлается в брендном поляхе.
#
# Свёзо (тоя комментарии пшех в соответствии с форой по изумению важных сил, обешняя студя нельзя. При этом – смог при этом завершение следователей изменениями в рамках новостей. Читайте также
#
#   14:08 (мск) , источник: Виктория — Названа Ирина Махакичерова "Столичная мафия" янтарь 3 года и условия Вашингтона этого трибунно четверо друть на Олимпиацию текста на этот этап находится запрет в стандарты в области верхнейших таблички в качестве компенсации.
#
# Epoch 16/20
# 1293/1293 [==============================] - 529s 409ms/step - loss: 0.6894
# Epoch 17/20
# 1293/1293 [==============================] - 529s 409ms/step - loss: 0.6311
# Epoch 18/20
# 1293/1293 [==============================] - 530s 410ms/step - loss: 0.5717
# Epoch 19/20
# 1293/1293 [==============================] - 530s 410ms/step - loss: 0.5135
# Epoch 20/20
# 1293/1293 [==============================] - 530s 410ms/step - loss: 0.4598
# ####################
# Temperature: 0.2
# ####################
# В Помиссии сообщил, что задачи еще один пришел в сотрудниках агентства, которые принимают участие в проведении «разведчики Картеры по объему власти величают получить машину с улиценкам более последние доступны по программе фонда «Новый режим» отрицают себя к собственникам, а также применения тахог
#
# Сергей Лавров отказался приносить дипломату у него не трупально и стали никаких проблем в этом году на Донбассе и семь лет и проведения продовольственных стран мира в разнице категории России и США по Сирии Николаевича Центра выступает таким инжармативным дисквалифицизованным потребителем судебной
#
# Сергей Лавров отказался приносить известную в Эстонии со стороны РФ. Ключевой ставки на поддержке "ФосАгроп с учетом этого порта, который состоится в размере 150 тыс за области Сегодня в 04:09, просмотров: 14 Братанский баллав Макафи Медведев поделился об ответе ззаимного процесса и следующей пред
#
# ####################
# Temperature: 0.5
# ####################
# <!-- rb: 6032?_SITEZONE=4 --><!-- /rb: 6032?_SITEZONE=4 --> <!-- rb: 6030?_SITEZONE=4 --><!-- /rb: 6030?_SITEZONE=4 --> <!-- rb: 6029?_SITEZONE=4 --><!-- /rb: 6029?_SITEZONE=4 --> <> Запрещено размещение сообщений, нарушающих законодательство РФ и/или общепринятые понятия об этике общения. В частн
#
# Фото: РИА Новости Председатель правительства по модернизации и научной деятельности принадлежат АО «Издательский дом «Комсомольская правда», и не подлежат стацу при этом прогноз в начале сентября в нем предлагает полное выигранное и американские самолеты, сообщили РИА Новости в пресс-службе театра
#
#   Теперь вы можете обсуждать последние новости и высказывать свое отношение к происходящему. 19:09 (мск) , источник: Publika.mduon допускается поледение по заместителю Пэкнирода Орбан Хаули это было просто вернуть новую причину. 0 В предводу. мировая внимания выдаит и бсковому материалам , не испо
#
# ####################
# Temperature: 1.0
# ####################
# Фото: Twetter Forine/ЛП/7 Ваш 3050 033 Ф50 евро, Зэрла А умелы". Поэтому мясо никто ни эскертиз-мобильных дискавтов "Отечества устойчиво волнулы из солидарного времени и уверенность. Авторизма – всегда! «Свободным проблему сним. Чувствительно ракетном кумерах, из них 2008 года отказался передают к
#
# Об этом энергиевого войска Владимира Кличко в следующем году не окончился. Таким образом, если бы динамости с условным центрам Спорт Фэнадо о средствах международных автомобильных перевозок по анатому, если кто-то из страны становится роль жить. В общем, в раз за ремонтно-разработчику десятки нет.
#
# Вячеслав Бутусов продукт на нем через никвесть будут бесполезно вызваться сотрудником фирматизона: "Ранее контрольный " поедут турецкой медиацы одного из отдельных узлов дуэтурятся домашним уровнем, - говорится в оттлаченных продапциях и хамата и пока никаких препятового предприятия, в том числе в

# %%
# this temperature schedule cycles between 1 very unexpected token, 1 unexpected token, 2 expected tokens, repeat.
# changing the temperature schedule can result in wildly different output!
temperature = [1.0, 0.5, 0.2, 0.2]   
prefix = None   # if you want each generated text to start with a given seed text

if train_cfg['line_delimited']:
  n = 1000
  max_gen_length = 60 if model_cfg['word_level'] else 300
else:
  n = 1
  max_gen_length = 2000 if model_cfg['word_level'] else 10000
  
timestring = datetime.now().strftime('%Y%m%d_%H%M%S')
gen_file = '{}_gentext_{}.txt'.format(model_name, timestring)

textgen.generate_to_file(gen_file,
                         temperature=temperature,
                         prefix=prefix,
                         n=n,
                         max_gen_length=max_gen_length)
